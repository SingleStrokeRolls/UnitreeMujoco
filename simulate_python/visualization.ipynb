# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./csv/1333.csv')
df['acc_mag'] = np.sqrt(df['acc_x']**2 + df['acc_y']**2 + df['acc_z']**2)
df['gyro_mag'] = np.sqrt(df['gyro_x']**2 + df['gyro_y']**2 + df['gyro_z']**2)

df = df.iloc[:-45,:]

print(df.iloc[10:20,-3:])

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 12))

df.plot(x='t', y='acc_mag', ax=ax1, color='red', title='Acceleration')
ax1.set_ylabel('acc_mag')
ax1.grid(True, alpha=0.3)
 
df.plot(x='t', y='gyro_mag', ax=ax2, color='green', title='Gyro')
ax2.set_ylabel('gyro_mag')
ax2.grid(True, alpha=0.3)

df.plot(x='t', y='tof', ax=ax3, color='blue', title='ToF')
ax3.set_ylabel('tof')
ax3.set_xlabel('Time (t)')
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
#          tof    acc_mag  gyro_mag
# 10  1.462701  25.696135  0.578946
# 11  1.464268  29.663313  0.639222
# 12  1.466115  28.327676  0.704274
# 13  1.468228  25.987594  0.770016
# 14  1.470572  30.743399  0.836284
# 15  1.473213  29.181084  0.900185
# 16  1.476140  27.156914  0.966487
# 17  1.479334  27.685594  1.030162
# 18  1.482808  28.191287  1.096695
# 19  1.486568  27.813867  1.163525
